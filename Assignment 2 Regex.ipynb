# %%
data = [

    "User: Mahipal | Phone: 9876543210 | Email: mahi@gmail.com | Amount: Rs.5000",

    "User: Ravi | Phone: 98765abc10 | Email: ravi#gmail.com | Amount: USD300",

    "User: NULL | Phone: 9123456789 | Email: test@yahoo.com | Amount: Rs.7000",

    "User: Ankit | Phone: 9999999999 | Email: ankit@gmail.com | Amount: Rs.0",

    "User: Sita | Phone: 8888888888 | Email: sita@gmail.com | Amount: Rs.-100"

]

 

"""

1.HANDLE EXCEPTIONS

Safely process each record

Skip bad records but log errors

 

2. USE ASSERT

Ensure:

User name is not NULL

Amount > 0

 

3. REGEX EXTRACTION

Extract:

name

phone (valid 10 digits only)

email (valid format)

amount (only numbers)

 

4. ADVANCED REGEX

Extract currency:

Rs

USD

 

5. STRING CLEANING

lowercase everything

remove special characters

 

 

6. FINAL OUTPUT

Return clean structured dataset:

[

 {'name': 'mahipal', 'phone': '9876543210', 'email': 'mahi@gmail.com', 'amount': 5000, 'currency': 'rs'},

 ...

]

"""
# Out:
# "\n\n1.HANDLE EXCEPTIONS\n\nSafely process each record\n\nSkip bad records but log errors\n\n\n\n2. USE ASSERT\n\nEnsure:\n\nUser name is not NULL\n\nAmount > 0\n\n\n\n3. REGEX EXTRACTION\n\nExtract:\n\nname\n\nphone (valid 10 digits only)\n\nemail (valid format)\n\namount (only numbers)\n\n\n\n4. ADVANCED REGEX\n\nExtract currency:\n\nRs\n\nUSD\n\n\n\n5. STRING CLEANING\n\nlowercase everything\n\nremove special characters\n\n\n\n\n\n6. FINAL OUTPUT\n\nReturn clean structured dataset:\n\n[\n\n {'name': 'mahipal', 'phone': '9876543210', 'email': 'mahi@gmail.com', 'amount': 5000, 'currency': 'rs'},\n\n ...\n\n]\n\n"

# %%
import re

data = [
    "User: Mahipal | Phone: 9876543210 | Email: mahi@gmail.com | Amount: Rs.5000",
    "User: Ravi | Phone: 98765abc10 | Email: ravi#gmail.com | Amount: USD300",
    "User: NULL | Phone: 9123456789 | Email: test@yahoo.com | Amount: Rs.7000",
    "User: Ankit | Phone: 9999999999 | Email: ankit@gmail.com | Amount: Rs.0",
    "User: Sita | Phone: 8888888888 | Email: sita@gmail.com | Amount: Rs.-100"
]

def process_data(records):
    clean_dataset = []
    
    for entry in records:
        try:
            # 3 & 4. REGEX EXTRACTION
            name_match = re.search(r"User:\s*([^|]+)", entry)
            phone_match = re.search(r"Phone:\s*(\d{10})(?:\s|\||$)", entry)
            email_match = re.search(r"Email:\s*([\w\.-]+@[\w\.-]+\.\w+)", entry)
            # Extracts currency (Rs/USD) and amount numbers separately
            money_match = re.search(r"Amount:\s*([A-Za-z]+)\.?(-?\d+)", entry)

            if not all([name_match, phone_match, email_match, money_match]):
                raise ValueError("Skipping: Invalid format or missing fields")

            name = name_match.group(1).strip()
            phone = phone_match.group(1)
            email = email_match.group(1)
            currency = money_match.group(1)
            amount = int(money_match.group(2))

            # 2. USE ASSERT
            assert name.upper() != "NULL", "User name is NULL"
            assert amount > 0, f"Amount {amount} is not > 0"

            # 5. STRING CLEANING (Lowercase & remove special chars from currency)
            # 6. FINAL OUTPUT (Structured List)
            clean_dataset.append({
                'name': name.lower(),
                'phone': phone,
                'email': email.lower(),
                'amount': amount,
                'currency': re.sub(r'[^a-zA-Z]', '', currency).lower()
            })

        except (ValueError, AssertionError) as e:
            # 1. HANDLE EXCEPTIONS
            print(f"Log Error: {e}")
            continue

    return clean_dataset

# Run and display result
final_output = process_data(data)
print("\nFinal Cleaned Dataset:")
print(final_output)
# Out:
# Log Error: Skipping: Invalid format or missing fields
# Log Error: User name is NULL
# Log Error: Amount 0 is not > 0
# Log Error: Amount -100 is not > 0
#
# Final Cleaned Dataset:
# [{'name': 'mahipal', 'phone': '9876543210', 'email': 'mahi@gmail.com', 'amount': 5000, 'currency': 'rs'}]
